# %%
import os
import requests
import json
from datetime import timedelta,datetime, date
from decimal import Decimal
import pandas as pd 
from io import StringIO 
import boto3



def get_tc():
    now = datetime.now() - timedelta(1)
    CURRENT_DAY=now.strftime("%Y%m%d")

    url = 'https://api.estadisticasbcra.com/usd_of'
    header = {'Authorization': 'BEARER eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE2OTc4MDY3NjksInR5cGUiOiJleHRlcm5hbCIsInVzZXIiOiJtYmluZWxsb0BpdGJhLmVkdS5hciJ9.uSFM9pbSz--7sPWUlfMOZ92_UAzYLLEua620qKmE3A7ttK5G0zA9P7n8jPfNOhu7bMqJW344Utupaq-NsgWSUA'}
    r = requests.get(url, headers=header)
    #print(r.text)

    j = r.json()
    tc = j
    df = pd.DataFrame(tc, columns=['d', 'v'])
    df = df.rename(columns={"d": "Dia", "v": "TC"})
    print(df)
    
    return df

def upload_s3 (file):
    # CREO EL NOMBRE DEL FILE 
    today = datetime.now()
    yesterday = today - timedelta(days=1)
    date = yesterday.strftime("%Y-%m-%d")
    filename = 'tc_oficial/csv/historico/file_'+date+'.csv'
    print(f"df_{date}")

    # LO TIRO EN S3

    bucket = 'lemoncash-data-cvu' 
    csv_buffer = StringIO()
    file.to_csv(csv_buffer)
    dt = datetime.now()
    s3_resource = boto3.resource('s3')
    print("hasta aca no rompe")
    s3_resource.Object(bucket, filename).put(Body=csv_buffer.getvalue())
    print("no rompio")
    print(file)
    print('subido a s3')

def main():
    info = get_tc()
    upload_s3(info)

if __name__ == "__main__":
    main()
# Out:
#              Dia      TC
# 0     2002-03-04    2.01
# 1     2002-03-05    1.99
# 2     2002-03-06    2.05
# 3     2002-03-07    2.14
# 4     2002-03-08    2.20
# ...          ...     ...
# 5064  2022-10-18  152.83
# 5065  2022-10-19  153.17
# 5066  2022-10-20  153.50
# 5067  2022-10-21  153.81
# 5068  2022-10-24  154.74
#
# [5069 rows x 2 columns]
# df_2022-10-24
# hasta aca no rompe
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In [48], line 55
#      52     upload_s3(info)
#      54 if __name__ == "__main__":
# ---> 55     main()
#
# Cell In [48], line 52, in main()
#      50 def main():
#      51     info = get_tc()
# ---> 52     upload_s3(info)
#
# Cell In [48], line 45, in upload_s3(file)
#      43 s3_resource = boto3.resource('s3')
#      44 print("hasta aca no rompe")
# ---> 45 s3_resource.Object(bucket, filename).put(Body=csv_buffer.getvalue())
# ...

# %%
from distutils import text_file
import pandas as pd 
import os 
import requests
from decimal import Decimal
import os  
from pathlib import Path
from datetime import timedelta
from datetime import timedelta,datetime, date
import pandas as pd 
import boto3
from io import StringIO 
import json 

#me devuelve una linea con la info de ayer --> [dia, tc]
def get_tc():
    url = 'https://api.estadisticasbcra.com/usd_of'
    header = {'Authorization': 'BEARER eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE2OTc4MDY3NjksInR5cGUiOiJleHRlcm5hbCIsInVzZXIiOiJtYmluZWxsb0BpdGJhLmVkdS5hciJ9.uSFM9pbSz--7sPWUlfMOZ92_UAzYLLEua620qKmE3A7ttK5G0zA9P7n8jPfNOhu7bMqJW344Utupaq-NsgWSUA'}
    r = requests.get(url, headers=header)
    j = r.json()
    tc = j[len(j)-1]
    dia = datetime.strptime(tc['d'], '%Y-%m-%d').date()
    cot = round(Decimal(tc['v']),2)
    df = pd.DataFrame({'Dia': dia, 'TC': cot}, index=[1])
    return df

def upload_s3 (file):
    # CREO EL NOMBRE DEL FILE 
    today = datetime.now()
    yesterday = today - timedelta(days=1)
    date = yesterday.strftime("%Y-%m-%d")
    filename = 'tc_oficial/csv/'+date+'/file_'+date+'.csv'
    print(f"df_{date}")

    # LO TIRO EN S3

    bucket = 'lemoncash-data-cvu' 
    csv_buffer = StringIO()
    file.to_csv(csv_buffer)
    dt = datetime.now()
    s3_resource = boto3.resource('s3')
    print("hasta aca no rompe")
    s3_resource.Object(bucket, filename).put(Body=csv_buffer.getvalue())
    print("no rompio")
    print(file)
    print('subido a s3')

def main():
    info = get_tc()
    upload_s3(info)

if __name__ == "__main__":
    main()
# Out:
# df_2022-10-19
# hasta aca no rompe
# no rompio
#           Dia      TC
# 1  2022-10-19  153.17
# subido a s3

# %%
from distutils import text_file
import pandas as pd 
import os 
import requests
from decimal import Decimal
import os  
from pathlib import Path
from datetime import timedelta,datetime, date
import pandas as pd 
import boto3
from io import StringIO 
import json 

#me devuelve una linea con la info de ayer --> [dia, tc]
def get_tc():
    url = 'https://api.estadisticasbcra.com/usd_of'
    header = {'Authorization': 'BEARER eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE2OTc2NDYwNjQsInR5cGUiOiJleHRlcm5hbCIsInVzZXIiOiJiaW5lbGxvbWF0aWFzQGdtYWlsLmNvbSJ9.gTybUbxZeGyklho2Z2bfiILWRt_1NJwsfjWb4KgF8yYOAHpLOxi51rydwZrYCbF7-y80EhyfmzrKb0S6uGLgPw'}
    r = requests.get(url, headers=header)
    j = r.json()
    tc = j[len(j)-1]
    dia = datetime.strptime(tc['d'], '%Y-%m-%d').date()
    cot = round(Decimal(tc['v']),2)
    df = pd.DataFrame({'Dia': dia, 'TC': cot}, index=[1])
    return df




def check_date():
    today = datetime.now()
    yesterday = today - timedelta(days=1)
    date = yesterday.strftime("%Y-%m-%d")
    a = get_tc()
    print(a)
    b = a._get_value(1,'Dia')
    print(b)
    if b == yesterday.date():
        print('go_on')
    else:
        print('change_date_to_today')

check_date()
# Out:
#           Dia      TC
# 1  2022-10-24  154.74
# 2022-10-24
# go_on
